# %%
import numpy as np
from PIL import Image
from os import path
import matplotlib.pyplot as plt
import random
import matplotlib.pylab as pylab

# %%
from wordcloud import WordCloud, STOPWORDS
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

d = path.dirname('Wong_et_al-2017-Groundwater.txt')
d

# Read the whole text.
text = open(path.join(d, 'Wong_et_al-2017-Groundwater.txt')).read()

# %%
# preprocessing the text a little bit
text = text.replace("viruses", "virus")
text = text.replace("HAdV", "adenovirus")
text1 = text

# adding movie script specific stopwords
stopwords = set(STOPWORDS)
stopwords.add("int")
stopwords.add("ext")
stopwords.add("et")
stopwords.add("al")
stopwords.add("Wong")
stopwords.add("virus")
stopwords.add("NA")
stopwords.add("study")
stopwords.add("since")
stopwords.add("using")
stopwords.add("different")
stopwords.add("one")

# %%
# %matplotlib inline

wc = WordCloud(max_words=1000,  stopwords=stopwords, margin=10,
               random_state=1).generate(text1)
# store default colored image
default_colors = wc.to_array()
plt.figure(figsize=(13, 13))
plt.imshow(default_colors, interpolation="bilinear")
plt.title("Applying Quantitative Molecular Tools for Virus Transport Studies: Opportunities and Challenges (2017)", 
          fontsize=15)
plt.axis("off")
plt.show()

# %%
text2 = open(path.join(d, 'Wong_et_al_2016_Rapid_microbiome_changes_in_freshl.txt')).read()

# %%
# preprocessing the text a little bit
text2 = text2.replace("samples", "sample")
text2 = text2.replace("cowpat", "fecal")
text2 = text2.replace("feces", "fecal")
text2 = text2.replace("fecals", "fecal")
text2 = text2.replace("Wong", "wong")
text2 = text2.replace("difference", "different")
text2 = text2.replace("increased", "increase")
text2 = text2.replace("community structure", "microbiome")
text2 = text2.replace("bacteria", "microbiome")
text2 = text2.replace("studies", "study")

# adding movie script specific stopwords
stopwords.add("RA")
stopwords.add("S2")
stopwords.add("S1")
stopwords.add("U1")
stopwords.add("U2")
stopwords.add("et")
stopwords.add("al")
stopwords.add("wong")
stopwords.add("day")
stopwords.add("NA")
stopwords.add("study")
stopwords.add("since")
stopwords.add("using")
stopwords.add("different")
stopwords.add("sample")
stopwords.add("fecal")
stopwords.add("Figure")
stopwords.add("Figure")
stopwords.add("increase")
stopwords.add("level")
stopwords.add("also")
stopwords.add("Supplementary")
stopwords.add("due")

# %%
# %matplotlib inline

wc = WordCloud(max_words=1000,  stopwords=stopwords, margin=10,
               random_state=1).generate(text2)
# store default colored image
default_colors = wc.to_array()
plt.figure(figsize=(13, 13))
plt.imshow(default_colors, interpolation="bilinear")
plt.title("Rapid Microbiome Changes in Freshly Deposited Cow Feces under Field Conditions (2016)", fontsize=17)
plt.axis("off")
plt.show()

# %%
text3 = open(path.join(d, 'Wong_et_al_2010_Quantification_of_Enteric_Viruses_.txt')).read()

# %%
# preprocessing the text a little bit
text3 = text3.replace("samples", "sample")
text3 = text3.replace("cowpat", "fecal")
text3 = text3.replace("feces", "fecal")
text3 = text3.replace("fecals", "fecal")
text3 = text3.replace("Wong", "wong")
text3 = text3.replace("difference", "different")
text3 = text3.replace("increased", "increase")
text3 = text3.replace("community structure", "microbiome")
text3 = text3.replace("bacteria", "microbiome")
text3 = text3.replace("studies", "study")
text3 = text3.replace("viruses", "virus")
text3 = text3.replace("HAdV", "adenovirus")
text3 = text3.replace("levels", "level")
text3 = text3.replace("results", "result")
text3 = text3.replace("NV", "norovirus")
text3 = text3.replace("EV", "enterovirus")
text3 = text3.replace("HPyV", "polyomavirus")
text3 = text3.replace("used", "use")
text3 = text3.replace("Environ", "environment")

stopwords.add("Appl")
stopwords.add("result")
stopwords.add("MAD")
stopwords.add("Appl")
stopwords.add("previous")
stopwords.add("MAD")
stopwords.add("Appl")
stopwords.add("Table")
stopwords.add("class")
stopwords.add("time")
stopwords.add("Microbiol")
stopwords.add("use")

# %%
# %matplotlib inline

wc = WordCloud(max_words=1000,  stopwords=stopwords, margin=10,
               random_state=1).generate(text3)
# store default colored image
default_colors = wc.to_array()
plt.figure(figsize=(19, 19))
plt.imshow(default_colors, interpolation="bilinear")
plt.title("Quantification of Enteric Viruses, Pathogen Indicators, and Salmonella Bacteria in Class B Anaerobically Digested Biosolids by Culture and Molecular Methods (2010)", fontsize=17)
plt.axis("off")
plt.show()
